# %% [markdown]
# # Задание 01. Первое знакомство с ноутбуком и таблицей
#
# Выполняйте шаги по порядку. Комментарии в коде оставлены намеренно — они помогают понимать, что делает каждая ячейка.
# В конце скачайте ноутбук (File → Download → .ipynb) и сдайте.

# %% [markdown]
# ## Шаг 1. Привет, мир!
#
# Запустите ячейку ниже (Shift+Enter).

# %%
print("Привет, это мой первый ноутбук!")

# %% [markdown]
# ## Шаг 2. Простые вычисления
#
# Python умеет считать. Запустите и посмотрите результат.

# %%
2 + 2 * 10

# %% [markdown]
# ## Шаг 3. Создадим таблицу
#
# Ниже создаётся таблица (DataFrame) прямо в ноутбуке — без файла.

# %%
import pandas as pd

df = pd.DataFrame({
    "название": ["Книга", "Ручка", "Тетрадь", "Карандаш"],
    "цена": [500, 40, 90, 30],
    "количество": [2, 5, 3, 1],
})
df

# %% [markdown]
# ## Шаг 4. Смотрим и считаем
#
# Посмотрите на таблицу: столбцы, сумму цены, общую стоимость по строкам.

# %%
df
df["цена"].sum()

# %%
df["итого"] = df["цена"] * df["количество"]
df

# %% [markdown]
# ## Шаг 5. Ваши выводы
#
# Замените текст ниже на свои слова: что вы узнали о ноутбуке? Что нового сделали? Какие цифры получились?

# %% [markdown]
# **Мои выводы:**
#
# - ...
# - ...
