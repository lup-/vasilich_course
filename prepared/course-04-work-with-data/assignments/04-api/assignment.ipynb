# %% [markdown]
# # Задание 04. Данные из API: погода
#
# Получим прогноз погоды для вашего города через публичный API Open-Meteo (без ключа).
# Документация: https://open-meteo.com

# %% [markdown]
# ## Шаг 1. Запрос к API

# %%
import requests
import pandas as pd

# Координаты Москвы; замените на свой город
url = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 55.75,
    "longitude": 37.62,
    "daily": ["temperature_2m_max", "temperature_2m_min"],
    "timezone": "Europe/Moscow",
}
resp = requests.get(url, params=params)
print("Статус:", resp.status_code)
data = resp.json()
print(list(data.keys()))

# %% [markdown]
# ## Шаг 2. Превращаем JSON в таблицу

# %%
days = data["daily"]["time"]
tmax = data["daily"]["temperature_2m_max"]
tmin = data["daily"]["temperature_2m_min"]

df = pd.DataFrame({"дата": days, "макс": tmax, "мин": tmin})
df

# %% [markdown]
# ## Шаг 3. Минимум и максимум за период

# %%
print("Самая тёплая:", df.loc[df["макс"].idxmax()].to_dict())
print("Самая холодная:", df.loc[df["мин"].idxmin()].to_dict())
print("Средний максимум:", df["макс"].mean())

# %% [markdown]
# ## Шаг 4. График

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df["дата"], df["макс"], marker="o", label="Макс")
plt.plot(df["дата"], df["мин"], marker="o", label="Мин")
plt.title("Прогноз температуры")
plt.xlabel("Дата")
plt.ylabel("Температура, °C")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Шаг 5. Выводы
#
# Что показывает прогноз? Где самое тёплое/холодное время?

# %% [markdown]
# **Выводы:**
#
# - ...
