# %% [markdown]
# # Задание 01. Знакомство с Gemini CLI: первая автоматизация
#
# Цель — установить терминального агента и получить первый реальный результат (файлы), а не просто «ответ».

# %% [markdown]
# ## Шаг 1. Установка
#
# В терминале (Linux/macOS или WSL) выполните установку. Запишите вывод.

# %%
# В терминале, НЕ в этом ноутбуке:
# npm install -g @google/gemini-cli
# gemini
# Впишите сюда вывод установки и версию:
print("Вывод установки:", "...")
print("Версия:", "...")

# %% [markdown]
# ## Шаг 2. Первая задача-действие
#
# Запустите gemini и дайте задачу создать файлы. Запишите, что агент показал.

# %%
# В gemini:
# «Создай в этой папке подпапку задание. Создай файл план.md с пятью шагами работы агента и файл привет.txt со словом привет. Покажи содержимое обоих.»
print("Что агент показывал:", "...")
print("Какие инструменты вызывал:", "...")

# %% [markdown]
# ## Шаг 3. Проверка результата
#
# Откройте созданные файлы и впишите их содержимое сюда.

# %%
import os
print("Файлы в папке:", os.listdir("."))
print("план.md существует:", os.path.exists("план.md"))
print("привет.txt существует:", os.path.exists("привет.txt"))

# %% [markdown]
# ## Шаг 4. Вопросы на закрепление
#
# Ответьте текстом.

# %% [markdown]
# **Мои выводы:**
#
# - Чем агент (Gemini CLI) отличается от чат-бота: ...
# - Какие инструменты он использует: ...
# - Как я проверил результат: ...
# - Какая трудность возникла и как решил: ...
