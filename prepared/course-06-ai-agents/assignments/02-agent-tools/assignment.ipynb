# %% [markdown]
# # Задание 02. Инструменты агента: файлы, код, поиск
#
# Научимся «видеть» инструменты в действии и понимать, когда агент действительно что-то делает, а когда «придумывает».

# %% [markdown]
# ## Шаг 1. Задача с файлом
#
# Дайте агенту (в Gemini CLI или другом) задачу с файлом. Запишите, какой инструмент вызывался.

# %%
print("Задача:", "посчитай сумму в sales.csv и сохрани результат в файл")
print("Вызванные инструменты:", "...")
print("Результат вызова (что показал агент):", "...")

# %% [markdown]
# ## Шаг 2. Задача с кодом
#
# Попросите агента посчитать и показать код. Сравните с ручным расчётом.

# %%
# Пример: сумма чисел от 1 до 10 должна быть 55.
print("Ответ агента:", "...")
print("Мой расчёт:", 55)
print("Совпадает?", "...")

# %% [markdown]
# ## Шаг 3. Поиск в интернете
#
# Попросите агента найти свежий факт и показать источник. Есть ли у него инструмент поиска?

# %%
print("Есть ли поиск:", "...")
print("Что нашёл:", "...")
print("Источник:", "...")

# %% [markdown]
# ## Шаг 4. Ловим «придумку»
#
# Задайте вопрос, где агент может «придумать» ответ, и потребуйте вызов инструмента.

# %%
print("Вопрос:", "какой файл лежит в этой папке? — не отвечай по памяти, вызови инструмент")
print("Что сделал агент:", "...")
print("Это был вызов инструмента или текст?", "...")

# %% [markdown]
# **Мои выводы:**
#
# - Как отличить «делает» от «отвечает»: ...
# - Какие инструменты видел: ...
# - Что понял про проверку: ...
