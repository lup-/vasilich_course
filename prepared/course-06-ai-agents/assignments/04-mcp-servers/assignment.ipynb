# %% [markdown]
# # Задание 04. Подключение готовых MCP-серверов
#
# Подключим готовый MCP-сервер к агенту (Gemini CLI) и проверим новые инструменты.

# %% [markdown]
# ## Шаг 1. Проверка поддержки MCP
#
# Спросите у агента, поддерживает ли он MCP, и запишите ответ.

# %%
print("Вопрос агенту:", "Ты умеешь подключать MCP-серверы? Покажи, как это делается в твоей версии.")
print("Ответ:", "...")

# %% [markdown]
# ## Шаг 2. Подключение файлового сервера
#
# Найдите в документации вашей версии, как добавить MCP-сервер в конфиг, и подключите сервер доступа к папке. Впишите конфиг сюда.

# %%
config = '''
{
  "mcpServers": {
    "filesystem": {
      "command": "npx",
      "args": ["-y", "@modelcontextprotocol/server-filesystem", "/path/to/folder"]
    }
  }
}
'''
print("Мой конфиг:", config)

# %% [markdown]
# ## Шаг 3. Проверка инструментов
#
# Перезапустите агента и спросите, какие инструменты доступны.

# %%
print("Вопрос агенту:", "Какие инструменты тебе доступны? Покажи список.")
print("Ответ (инструменты):", "...")
print("Использовал ли агент инструменты по задаче?", "...")

# %% [markdown]
# ## Шаг 4. Вопросы
#
# Ответьте текстом.

# %% [markdown]
# **Мои выводы:**
#
# - Что такое MCP и зачем: ...
# - Как подключить сервер (шаги): ...
# - Почему важно ограничивать папки: ...
# - Какие 2 сервера хочу подключить дальше: ...
