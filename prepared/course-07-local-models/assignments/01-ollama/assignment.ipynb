# %% [markdown]
# # Задание 01. Установка Ollama и первая модель
#
# Цель — установить Ollama, скачать маленькую модель и получить первый ответ локальной модели.

# %% [markdown]
# ## Шаг 1. Установка
#
# Установите Ollama по документации (https://docs.ollama.com/). Запишите версию.

# %%
# В терминале: ollama --version
print("Версия Ollama:", "...")

# %% [markdown]
# ## Шаг 2. Скачивание модели
#
# Скачайте маленькую модель. Запишите, сколько времени заняло.

# %%
# В терминале: ollama pull qwen2.5:3b
print("Модель скачана?", "...")
print("Время скачивания:", "...")

# %% [markdown]
# ## Шаг 3. Запуск и первый вопрос
#
# Запустите модель и задайте вопрос. Запишите ответ.

# %%
# В терминале: ollama run qwen2.5:3b
# Затем: «Привет! Расскажи, кто ты.»
print("Ответ модели:", "...")

# %% [markdown]
# ## Шаг 4. Вызов без чата
#
# Одна команда, без интерактивного режима.

# %%
# В терминале: ollama run qwen2.5:3b "Назови столицу Франции."
print("Ответ:", "...")

# %% [markdown]
# ## Шаг 5. Список моделей и место
#
# Проверьте скачанные модели.

# %%
# В терминале: ollama list
print("Список моделей:", "...")
print("Сколько места заняла модель:", "...")

# %% [markdown]
# **Мои выводы:**
#
# - Как установить Ollama: ...
# - Как скачать и запустить модель: ...
# - Какие команды выучил: ...
# - Что понял про офлайн-работу: ...
