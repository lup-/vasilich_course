# %% [markdown]
# # Задание 02. Выбор модели под своё железо
#
# Определим характеристики компьютера и выберем подходящие модели.

# %% [markdown]
# ## Шаг 1. ОЗУ
#
# Определите оперативную память.

# %%
import os
# Linux: free -h
# Windows: Диспетчер задач → Производительность
# macOS: «Об этом Mac»
print("ОЗУ, ГБ:", "...")

# %% [markdown]
# ## Шаг 2. Видеокарта и процессор
#
# Есть ли GPU? Сколько VRAM? Какой CPU?

# %%
# Linux: nvidia-smi (если есть), lscpu | grep 'Model name'
print("Видеокарта:", "...")
print("VRAM, ГБ:", "...")
print("Процессор:", "...")

# %% [markdown]
# ## Шаг 3. Расчёт доступной памяти
#
# ОЗУ минус ~2–4 ГБ на систему и контекст.

# %%
ram_gb = 16   # впишите своё ОЗУ
available = ram_gb - 3
print(f"Доступно под модель: ~{available} ГБ")
print("Значит подходят модели с файлом до ~", available, "ГБ")

# %% [markdown]
# ## Шаг 4. Выбор моделей
#
# Найдите в каталоге Ollama 2 подходящие модели.

# %%
print("Модель 1:", "...", "| квантование:", "...")
print("Модель 2:", "...", "| квантование:", "...")
print("Почему подходят:", "...")

# %% [markdown]
# ## Шаг 5. Проверка у агента
#
# Попросите агента проверить ваш выбор.

# %%
print("Вопрос агенту:", "Подходят ли эти модели для моего компьютера (ОЗУ ..., GPU ...)? Предложи альтернативы.")
print("Ответ агента:", "...")

# %% [markdown]
# **Мои выводы:**
#
# - Характеристики моего компьютера: ...
# - Какие модели мне подходят и почему: ...
# - Что такое квантование Q4: ...
# - Что делать, если модель не влезает: ...
