# %% [markdown]
# # Задание 04. Open WebUI: свой веб-чат
#
# Установим веб-интерфейс для локальных моделей и подключим его к Ollama.

# %% [markdown]
# ## Шаг 1. Установка
#
# Сверьтесь с документацией (https://docs.openwebui.com/), установите и запустите.

# %%
print("Команда установки:", "...")
print("Команда запуска:", "...")
print("Адрес в браузере:", "http://localhost:8080")

# %% [markdown]
# ## Шаг 2. Первый вход
#
# Создайте локальный аккаунт. Запишите, что потребовалось.

# %%
print("Аккаунт создан?", "...")
print("Что потребовалось:", "...")

# %% [markdown]
# ## Шаг 3. Подключение Ollama
#
# Добавьте Ollama как источник моделей (адрес http://localhost:11434).

# %%
print("Источник Ollama подключён?", "...")
print("Какие модели видны:", "...")

# %% [markdown]
# ## Шаг 4. Чат в браузере
#
# Задайте модели 3 вопроса в веб-чате.

# %%
print("Вопрос 1 и ответ:", "...")
print("Вопрос 2 и ответ:", "...")
print("Вопрос 3 и ответ:", "...")

# %% [markdown]
# ## Шаг 5. Проверка приватности
#
# Почему данные остаются локально?

# %%
print("Где работают модели:", "...")
print("Уходят ли данные в облако:", "...")
print("Почему:", "...")

# %% [markdown]
# **Мои выводы:**
#
# - Как установить Open WebUI: ...
# - Как подключить Ollama: ...
# - Чем удобен веб-интерфейс: ...
# - Почему это «личный ChatGPT» без облака: ...
